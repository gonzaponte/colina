# %%
import numpy             as np
import pandas            as pd
import tables            as tb
import scipy.stats       as st
import matplotlib.pyplot as plt
import tomllib

from nbtools import auto_plot_style
from jupyfun import progressbar

in_range = lambda x, a, b: (x>=a) & (x<b)

# %%
#%matplotlib inline
auto_plot_style()

# %%
sipms = pd.read_csv("../toy-mc/demo/images.csv"         , sep=" ", header=0)
fine  = pd.read_csv("../toy-mc/demo/detailed_images.csv", sep=" ", header=None).values
conf  = tomllib.loads(open("../toy-mc/demo/run.conf").read())

extent = conf["geometry"]["sipm_plane"]["sipm_size"] + conf["geometry"]["sipm_plane"]["sipm_gap"] 
extent = (-extent, extent)*2

# %%
for i in range(10):
    plt.figure(figsize=(15, 6))
    
    x, y = data.iloc[i, 1:3]
    
    img  = sipms.iloc[i:i+1].filter(regex="img_*").values
    n    = int(img.size**0.5)
    img  = img.reshape(10,10)

    img2 = fine[i]
    n    = int(img2.size**0.5)
    img2 = img2.reshape(n, n)
    
    plt.figure()
    plt.subplot(1, 2, 1)
    plt.imshow(img, origin="lower", extent=extent)
    plt.title(f"{x:.1f} {y:.1f}")

    plt.subplot(1, 2, 2)
    plt.imshow(img2, origin="lower", extent=extent)
    plt.tight_layout()
